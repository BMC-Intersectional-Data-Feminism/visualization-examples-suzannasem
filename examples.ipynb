# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('spotify.csv')

# %%
fig, ax = plt.subplots()
ax.plot(df['Date'], df['Shape of You'])
ax.ylabel('Number of Streams')
ax.xlabel('Date')
ax.set_xticks(df['Date'], df['Date'], rotation = 'vertical')
xticks = list(df['Date'])[]
xlabels = 
# ax.tick_params()
# Out:
# Text(0.5, 0, 'Date')

# %%
plt.plot(df['Date'], df['Shape of You'], label = 'Shape of You')
plt.plot(df['Date'], df['Despacito'], label = 'Despacito')
plt.ylabel('Number of Streams')
plt.xlabel('Date')
plt.legend()
plt.title('Streams of Popular Songs')
# Out:
# Text(0.5, 1.0, 'Streams of Popular Songs')
